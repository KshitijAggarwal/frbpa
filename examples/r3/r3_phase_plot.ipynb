# %%
from frbpa.plotting import make_obs_phase_plot
from frbpa.utils import get_params
import pylab as plt
# %matplotlib inline

# %%
params = get_params(1, 1.2)
plt.rcParams.update(params)

# %%
make_obs_phase_plot('r3_data.json', 16.35, ref_mjd=58369.30, nbins=40)
# Out:
# /lustre/aoc/observers/nm-10222/anaconda3/envs/temp/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
