# %%
from frbpa.plotting import make_phase_plot

# %%
make_phase_plot('r2_data.json', 35, 58344, show=True, nbins=10)
# Out:
# 2020-06-12 11:08:27,766 - _findfont_cached -matplotlib.font_manager - WARNING - findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# 2020-06-12 11:08:27,784 - _findfont_cached -matplotlib.font_manager - WARNING - findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# 2020-06-12 11:08:27,821 - _findfont_cached -matplotlib.font_manager - WARNING - findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
make_phase_plot('r2_data.json', 45, 58344, show=True, nbins=10)
